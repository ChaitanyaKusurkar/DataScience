# %%
import pandas as pd
# %pylab inline
from IPython.display import display
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df=pd.read_csv('final_test.csv')

# %%
pd.options.display.max_columns = None
display(df)
# Out:
#        Unnamed: 0  pokemonId   latitude   longitude appearedTimeOfDay  \
# 0          211925         98  53.873498   -2.392238         afternoon
# 1          250920         96  47.079587    2.400057         afternoon
# 2          159047        129  32.825052  -96.716915             night
# 3          238916         25  33.117660 -117.264534           morning
# 4           79251         13  42.257433  -71.849768             night
# 5           81398         13  44.493611   11.346219           evening
# 6          174974         58  37.602461 -122.022166             night
# 7          268752         43  42.278984  -87.830299             night
# 8          165332        129  50.816586   14.969206         afternoon
# 9           81111         13  45.497886    9.940962           evening
# 10         234588         10  35.735746  -78.649936             night
# 11         184849         46  45.496867 -122.873824             night
# ...

# %%
df.urban = df.urban.astype(int)
df.closeToWater=df.closeToWater.astype(int)
df.suburban=df.suburban.astype(int) 
df.midurban=df.midurban.astype(int) 
df.rural=df.rural.astype(int)

# %%
display(df)
# Out:
#        Unnamed: 0  pokemonId   latitude   longitude appearedTimeOfDay  \
# 0          211925         98  53.873498   -2.392238         afternoon
# 1          250920         96  47.079587    2.400057         afternoon
# 2          159047        129  32.825052  -96.716915             night
# 3          238916         25  33.117660 -117.264534           morning
# 4           79251         13  42.257433  -71.849768             night
# 5           81398         13  44.493611   11.346219           evening
# 6          174974         58  37.602461 -122.022166             night
# 7          268752         43  42.278984  -87.830299             night
# 8          165332        129  50.816586   14.969206         afternoon
# 9           81111         13  45.497886    9.940962           evening
# 10         234588         10  35.735746  -78.649936             night
# 11         184849         46  45.496867 -122.873824             night
# ...

# %%
X=pd.DataFrame()
X['pokemonId']=df['pokemonId']

# %%
del df['pokemonId']
del df['appearedTimeOfDay']
del df['continent']
del df['weather']
del df['Name']
del df['Type 1']
del df['Unnamed: 0']
df.urban = df.urban.astype(float)
df.closeToWater=df.closeToWater.astype(float)
df.suburban=df.suburban.astype(float) 
df.midurban=df.midurban.astype(float) 
df.rural=df.rural.astype(float)
display(df)
# Out:
#         latitude   longitude  appearedHour  appearedMinute  closeToWater  \
# 0      53.873498   -2.392238          12.0            59.0           0.0
# 1      47.079587    2.400057          15.0             5.0           0.0
# 2      32.825052  -96.716915           1.0            37.0           0.0
# 3      33.117660 -117.264534          10.0            52.0           1.0
# 4      42.257433  -71.849768           5.0             4.0           0.0
# 5      44.493611   11.346219          18.0            44.0           0.0
# 6      37.602461 -122.022166           1.0            26.0           1.0
# 7      42.278984  -87.830299           2.0            17.0           1.0
# 8      50.816586   14.969206          12.0            52.0           0.0
# 9      45.497886    9.940962          19.0            51.0           0.0
# 10     35.735746  -78.649936           4.0            29.0           0.0
# 11     45.496867 -122.873824           5.0            53.0           0.0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(penalty='l2', C=10)

# %%
model.fit(df,X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-c3d79b0f9bd7> in <module>()
#       1
# ----> 2 model.fit(df,X)
#
# C:\Users\Sunil Kusurkar\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.pyc in fit(self, X, y, sample_weight)
#    1140
#    1141         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1142                          order="C")
#    1143         check_classification_targets(y)
#    1144         self.classes_ = np.unique(y)
#
# C:\Users\Sunil Kusurkar\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     508     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...

# %%
from sklearn.metrics import accuracy_score
print "Logistic accuracy is %2.2f" % accuracy_score(df,model.predict(X))
